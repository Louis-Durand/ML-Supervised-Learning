# %%
import math
import numpy as np
import pylab as pl
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import Perceptron
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn import svm

# Convert categorical data into numerical data
df['Partnered'] = df['Partnered'].astype('category')
df['Partnered'] = df['Partnered'].cat.codes
df['Mature'] = df['Mature'].astype('category')
df['Mature'] = df['Mature'].cat.codes
df['Language'] = df['Language'].astype('category')
df['Language'] = df['Language'].cat.codes

X = df[[
    "Watch time(Minutes)",
    "Stream time(minutes)",
    "Peak viewers",
    "Average viewers",
    "Followers",
    "Followers gained",
    "Views gained",
    "Partnered",
    "Mature",
]]
y = df["Language"]

cv = KFold(n_splits=10, shuffle=True, random_state=None)
clf = svm.SVC()
scores = cross_val_score(clf, X, y, cv=cv)
print(scores.mean())

# %% [markdown]
# Prediction of the language of the streamer with the support vector classifier and performing cross-validation with 10 folds

# %% [markdown]
# The accuracy of the prediction is about 48,5%.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e02551f1-9953-47df-879b-6776493df133' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
